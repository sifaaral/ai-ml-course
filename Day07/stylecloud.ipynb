# %%
#pip install stylecloud

# %%
import stylecloud as sc

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch.png')

# %%
from IPython.display import Image
Image('ch.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt',icon_name='fas fa-truck', output_name='ch2.png')

# %%
from IPython.display import Image
Image('ch2.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt',icon_name='fas fa-star-and-crescent', output_name='ch4.png', background_color="red",colors="white")

# %%
from IPython.display import Image
Image('ch4.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt',icon_name='fas fa-calculator', output_name='ch6.png')

# %%
from IPython.display import Image
Image('ch6.png')
