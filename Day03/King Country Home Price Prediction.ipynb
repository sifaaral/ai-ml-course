# %% [markdown]
#  # WA Ev Fiyatları Tahmini

# %%
import pandas as pd # data dosyalarını okuma paketi
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import Ridge,Lasso,ElasticNet
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head(25)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
df.sample(3)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 14382  5101404351  20140702T000000  550000.0         4       2.75
# 19766  2597490030  20141002T000000  815000.0         4       3.50
# 2973   3278602670  20140930T000000  219500.0         1       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14382         2160      5005     1.0           0     0  ...      7
# 19766         3040      4006     2.0           0     0  ...      8
# 2973           820      1060     1.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 14382        1430            730      1987             0    98115  47.6971
# 19766        2350            690      2013             0    98029  47.5439
# 2973          760             60      2007             0    98126  47.5473
#
#           long  sqft_living15  sqft_lot15
# 14382 -122.302           1770        5326
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
abs(df.corr(numeric_only=True)['price'].sort_values(ascending=False))
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id               0.016762
# zipcode          0.053203
# Name: price, dtype: float64

# %%
df['age']=2024-df['yr_built']

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df['zipcode']=df['zipcode'].astype('category')

# %%
x=df[['sqft_living','grade','bathrooms','view','sqft_basement','bedrooms','waterfront','floors','age','zipcode']]
y=df[['price','sqft_living','age']]

# %%
x.head()
# Out:
#    sqft_living  grade  bathrooms  view  sqft_basement  bedrooms  waterfront  \
# 0         1180      7       1.00     0              0         3           0
# 1         2570      7       2.25     0            400         3           0
# 2          770      6       1.00     0              0         2           0
# 3         1960      7       3.00     0            910         4           0
# 4         1680      8       2.00     0              0         3           0
#
#    floors  age zipcode
# 0     1.0   69   98178
# 1     2.0   73   98125
# 2     1.0   91   98028
# 3     1.0   59   98136
# 4     1.0   37   98074

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
x.head()
# Out:
#    sqft_living  grade  bathrooms  view  sqft_basement  bedrooms  waterfront  \
# 0         1180      7       1.00     0              0         3           0
# 1         2570      7       2.25     0            400         3           0
# 2          770      6       1.00     0              0         2           0
# 3         1960      7       3.00     0            910         4           0
# 4         1680      8       2.00     0              0         3           0
#
#    floors  age  zipcode_98002  ...  zipcode_98146  zipcode_98148  \
# 0     1.0   69          False  ...          False          False
# 1     2.0   73          False  ...          False          False
# 2     1.0   91          False  ...          False          False
# 3     1.0   59          False  ...          False          False
# 4     1.0   37          False  ...          False          False
#
#    zipcode_98155  zipcode_98166  zipcode_98168  zipcode_98177  zipcode_98178  \
# ...

# %%
lr=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = lr.fit(x_train,y_train) #Makine öğrenmesi başladı

# %%
tahmin=lr.predict(x_test)

# %%
mean_squared_error(y_test,tahmin)**0.5
# Out:
# 99337.3117422109

# %%
r2_score(y_test,tahmin)
# Out:
# 0.9347260477036757

# %% [markdown]
# Hedef = r2_score>,80
# RMSE < $100K

# %%
sns.kdeplot(x=df['price']);

# %%
#df=df[df['bedrooms']>10]

# %%
from sklearn.linear_model import Ridge,Lasso,ElasticNet

# %%
R=Ridge()
L=Lasso()
E=ElasticNet()

# %%
Rmodel=R.fit(x_train,y_train)

# %%
tahmin2=Rmodel.predict(x_test)

# %%
mean_squared_error(y_test,tahmin2)**0.5 #Root Mean Squared Error Hata
# Out:
# 99436.00393420436

# %%
r2_score(y_test,tahmin2)
# Out:
# 0.9345962831788249
