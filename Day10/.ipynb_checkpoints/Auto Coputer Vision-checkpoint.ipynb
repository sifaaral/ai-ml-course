# %% [markdown]
# # Auto Coputer Vision

# %%
pip install cvlib
# Out:
# Requirement already satisfied: cvlib in /home/sifa/anaconda3/lib/python3.12/site-packages (0.2.7)
# Requirement already satisfied: numpy in /home/sifa/anaconda3/lib/python3.12/site-packages (from cvlib) (1.26.4)
# Requirement already satisfied: progressbar in /home/sifa/anaconda3/lib/python3.12/site-packages (from cvlib) (2.5)
# Requirement already satisfied: requests in /home/sifa/anaconda3/lib/python3.12/site-packages (from cvlib) (2.32.2)
# Requirement already satisfied: pillow in /home/sifa/anaconda3/lib/python3.12/site-packages (from cvlib) (9.4.0)
# Requirement already satisfied: imageio in /home/sifa/anaconda3/lib/python3.12/site-packages (from cvlib) (2.33.1)
# Requirement already satisfied: imutils in /home/sifa/anaconda3/lib/python3.12/site-packages (from cvlib) (0.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sifa/anaconda3/lib/python3.12/site-packages (from requests->cvlib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sifa/anaconda3/lib/python3.12/site-packages (from requests->cvlib) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sifa/anaconda3/lib/python3.12/site-packages (from requests->cvlib) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sifa/anaconda3/lib/python3.12/site-packages (from requests->cvlib) (2024.7.4)

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/sifa/anaconda3/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/sifa/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib
from cvlib.object_detection import draw_bbox
# Out:
# 2024-08-25 14:26:12.592947: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-25 14:26:12.593454: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-25 14:26:12.595742: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-25 14:26:12.603790: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-25 14:26:12.624223: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-25 14:26:12.627845: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-25 14:26:12.637109: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-25 14:26:13.485361: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
img=cv2.imread('cars.jpg')

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 box,label,count=cvlib.detect_common_objects(img)
#
# File ~/anaconda3/lib/python3.12/site-packages/cvlib/object_detection.py:125, in detect_common_objects(image, confidence, nms_thresh, model, enable_gpu)
#     123 if initialize:
#     124     classes = populate_class_labels()
# --> 125     net = cv2.dnn.readNet(weights_file_abs_path, config_file_abs_path)
#     126     initialize = False
#     128 # enables opencv dnn module to use CUDA on Nvidia card instead of cpu
#
# error: OpenCV(4.10.0) /io/opencv/modules/dnn/src/darknet/darknet_io.cpp:705: error: (-215:Assertion failed) separator_index < line.size() in function 'ReadDarknetFromCfgStream'

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('car')

# %%
label.count('person')

# %%
img=cv2.imread('g8.jpg')

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 box,label,count=cvlib.detect_common_objects(img)
#
# File ~/anaconda3/lib/python3.12/site-packages/cvlib/object_detection.py:125, in detect_common_objects(image, confidence, nms_thresh, model, enable_gpu)
#     123 if initialize:
#     124     classes = populate_class_labels()
# --> 125     net = cv2.dnn.readNet(weights_file_abs_path, config_file_abs_path)
#     126     initialize = False
#     128 # enables opencv dnn module to use CUDA on Nvidia card instead of cpu
#
# error: OpenCV(4.10.0) /io/opencv/modules/dnn/src/darknet/darknet_io.cpp:705: error: (-215:Assertion failed) separator_index < line.size() in function 'ReadDarknetFromCfgStream'

# %%
output=draw_bbox(img,box,label,count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 output=draw_bbox(img,box,label,count)
#
# NameError: name 'box' is not defined

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 plt.figure(figsize=(10,10))
# ----> 2 plt.imshow(output)
#
# NameError: name 'output' is not defined

# %%
label.count('person')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 label.count('person')
#
# NameError: name 'label' is not defined

# %%
img=cv2.imread('dogs.jpg')
box,label,count=cvlib.detect_common_objects(img)
output=draw_bbox(img,box,label,count)
plt.figure(figsize=(10,10))
plt.imshow(output)
# Out:
# [ WARN:0@169.145] global loadsave.cpp:241 findDecoder imread_('dogs.jpg.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 img=cv2.imread('dogs.jpg.jpg')
# ----> 2 box,label,count=cvlib.detect_common_objects(img)
#       3 output=draw_bbox(img,box,label,count)
#       4 plt.figure(figsize=(10,10))
#
# File ~/anaconda3/lib/python3.12/site-packages/cvlib/object_detection.py:77, in detect_common_objects(image, confidence, nms_thresh, model, enable_gpu)
#      66 def detect_common_objects(image, confidence=0.5, nms_thresh=0.3, model='yolov4', enable_gpu=False):
#      67     """A method to detect common objects
#      68     Args:
#      69         image: A colour image in a numpy array
#    (...)
#      74
#      75     """
# ---> 77     Height, Width = image.shape[:2]
#      78     scale = 0.00392
#      80     global classes
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
img=cv2.imread('mutfak.jpg')
box,label,count=cvlib.detect_common_objects(img)
output=draw_bbox(img,box,label,count)
plt.figure(figsize=(10,10))
plt.imshow(output)
# Out:
# [ WARN:0@195.016] global loadsave.cpp:241 findDecoder imread_('mutfak.jpg.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 img=cv2.imread('mutfak.jpg.jpg')
# ----> 2 box,label,count=cvlib.detect_common_objects(img)
#       3 output=draw_bbox(img,box,label,count)
#       4 plt.figure(figsize=(10,10))
#
# File ~/anaconda3/lib/python3.12/site-packages/cvlib/object_detection.py:77, in detect_common_objects(image, confidence, nms_thresh, model, enable_gpu)
#      66 def detect_common_objects(image, confidence=0.5, nms_thresh=0.3, model='yolov4', enable_gpu=False):
#      67     """A method to detect common objects
#      68     Args:
#      69         image: A colour image in a numpy array
#    (...)
#      74
#      75     """
# ---> 77     Height, Width = image.shape[:2]
#      78     scale = 0.00392
#      80     global classes
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
img=cv2.imread('kitchen.jpeg')
box,label,count=cvlib.detect_common_objects(img)
output=draw_bbox(img,box,label,count)
plt.figure(figsize=(10,10))
plt.imshow(output)
